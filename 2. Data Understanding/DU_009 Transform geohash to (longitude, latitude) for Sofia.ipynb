# %%
# All necessary imports for this notebook

import math
import pandas as pd
import geohash

# %%
# Load Air Tube Data into a Data Frame

df = pd.DataFrame(pd.read_csv('data_bg_2017.csv'))

# %%
# Extract longitude from geohash
def get_longitude(ghash):
    try:
        return geohash.decode(ghash)[0]
    except ValueError as e:
        print("value: {}, error: {}".format(ghash, e))
        return -1
    except TypeError as e:
        print("value: {}, error: {}".format(ghash, e))
        return -1

# Extract lattitude from geohash
def get_lattitude(ghash):
    try:
        return geohash.decode(ghash)[1]
    except ValueError as e:
        print("geohash: {}, error: {}".format(ghash, e))
        return -1
    except TypeError as e:
        print("geohash: {}, error: {}".format(ghash, e))
        return -1

# Assign longitude and lattitude
df['longitude'] = df['geohash'].apply(get_longitude)
df['latitude'] = df['geohash'].apply(get_lattitude)
# Out:
# value: m-2105171, error: geohash code is [0123456789bcdefghjkmnpqrstuvwxyz]+
# geohash: m-2105171, error: geohash code is [0123456789bcdefghjkmnpqrstuvwxyz]+

# %%
# Remove rows with an invalid geohash

df = df[(df['longitude'] != -1) & (df['latitude'] != -1)]

# %%
# Filter data only for Sofia

def distance(x1, x2, y1, y2):
    return math.sqrt((y1 - x1) ** 2 + (y2 - x2) ** 2)

sofia_center = [42.697708, 23.321867]
german_village = [42.609620, 23.410710]
sofia_radius = distance(*sofia_center, *german_village)

df['in_sofia'] = df[['longitude', 'latitude']].apply(
    lambda point: 1 if distance(*point, *sofia_center) < sofia_radius else 0, axis=1
)

# unique_geohashes = df['geohash'].unique()

# Save to CSV
# df[df.in_sofia == 1][['geohash', 'longitude', 'latitude']].to_csv('geohash_mapping_sofia_2017.csv', index=False)

sofia_df = df[df.in_sofia == 1]

sofia_df.head()
# Out:
#                     time      geohash  P1  P2  temperature  humidity  \
# 0   2017-09-06T20:00:00Z  sx8d5r7wmxr   9   8           14        55
# 1   2017-09-06T20:00:00Z  sx8d6zjg5h8   9   8            0         0
# 6   2017-09-06T20:00:00Z  sx8dem6pp1h  15  11           14        54
# 9   2017-09-06T20:00:00Z  sx8devjgkk2  14  13           18        10
# 12  2017-09-06T20:00:00Z  sx8d9g29ns5   0   0           17        55
#
#     pressure  longitude   latitude  in_sofia
# 0          0     42.580  23.351000         1
# 1          0     42.622  23.332000         1
# 6      94841     42.657  23.349000         1
# 9          0     42.655  23.375999         1
# 12     93535     42.645  23.281000         1

# %%
sofia_df.describe()
# Out:
#                   P1             P2    temperature       humidity  \
# count  419642.000000  419642.000000  419642.000000  419642.000000
# mean       43.176872      23.397098       8.939606      61.674442
# std        78.353541      39.862942      12.704712      22.505932
# min         0.000000       0.000000    -148.000000       0.000000
# 25%        10.000000       7.000000       4.000000      50.000000
# 50%        22.000000      13.000000       9.000000      66.000000
# 75%        45.000000      26.000000      14.000000      78.000000
# max      2000.000000    1000.000000      63.000000     100.000000
#
#             pressure      longitude       latitude  in_sofia
# count  419642.000000  419642.000000  419642.000000  419642.0
# mean    81517.876693      42.678531      23.323406       1.0
# std     33257.032365       0.029506       0.041544       0.0
# min         0.000000      42.580000      23.229000       1.0
# 25%     93982.000000      42.661000      23.291000       1.0
# 50%     94915.000000      42.680000      23.323999       1.0
# 75%     95513.000000      42.694000      23.355000       1.0
# max    162962.000000      42.804000      23.419001       1.0
